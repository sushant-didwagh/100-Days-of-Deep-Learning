# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x=df['cgpa'], y=df['resume_score'], hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
# First, ensure the package is installed correctly
# !pip install mlxtend

# Restart the kernel after installation
# (You'll need to manually restart the kernel in Jupyter)

# After restarting, import the module
from mlxtend.plotting import plot_decision_regions

# Alternatively, you can try using the system Python executable directly
import sys
# !{sys.executable} -m pip install mlxtend

# Then import after installation
from mlxtend.plotting import plot_decision_regions
# Out:
# ...
#   Using cached mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# ...
# Using cached mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Anaconda ALL Files\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Anaconda ALL Files\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Anaconda ALL Files\Lib\site-packages)
# 'C:\Anaconda' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Import the plot_decision_regions function from mlxtend library
from mlxtend.plotting import plot_decision_regions

# Now use the function
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# C:\Anaconda ALL Files\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   .. versionchanged:: 1.6
# <Axes: >
